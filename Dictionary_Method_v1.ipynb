# %%
# Dictionary Manip

rd_dict = {}
def instert_key(dict_i, key_i, container_value='0'):          
    dict_i[key_i] = container_value
#instert_key(a_dict, 'name', 'name')

def instert_keys_in_key(dict_i, key_i, container_value='0'):           
    for i in dict_i:
        dict_i[i][key_i] = container_value   
#instert_key(rd_dict, 'i', {})
#instert_key_in_key(rd_dict, 'a', [])
# rd_dict # {'i': {'a': []}}

def change_items(d_input, i_key, out_type='str'):             
    for i in d_input:
        print(i, i_key, '?', 'before:', d_input[i][i_key])
        itm = input('{}'.format(i))
        if itm == 'stop':
            return
        if itm == 'pass':
            pass
        if out_type == 'int' and itm != 'pass':
            d_input[i][i_key] = int(itm)
        elif out_type == 'float' and itm != 'pass':
            d_input[i][i_key] = float(itm)
        elif out_type == 'str' and itm != 'pass':
            d_input[i][i_key] = itm
        if out_type == 'list':
            d_input[i][i_key] = eval(itm)
#change_items(rd_dict, 'a', 'list')
#rd_dict

# %%
rd_dict = {}
def instert_key(dict_i, key_i, container_value='0'):          
    dict_i[key_i] = container_value
for i in 'ab':
    instert_key(rd_dict, 'dict_{}'.format(i), {})
    for f in range(2):
        instert_key(rd_dict['dict_{}'.format(i)], 'key_{}_{}'.format(i,f+1), 'item_{}_{}'.format(i,f+1))
rd_dict

# %%
dict_ids_ls=[]
def fill_dict_ids(d_id_ls, out_type='str'):
    keep_asking = True
    while keep_asking == True:
        input_cmd = input('input addition or command')
        if input_cmd == 'stop':
            keep_asking = False
            return d_id_ls
        
        if input_cmd == 'type':
            input_type = input('type the type')
            if input_type == 'int':
                out_type = input_type
            elif input_type == 'float':
                out_type = input_type
            elif input_type == 'str':
                out_type = input_type
            pass
        elif out_type == 'int' and type(int(input_cmd)) == int:
            d_id_ls+=[int(input_cmd)]
        elif out_type == 'float' and type(float(input_cmd)) == float:
            d_id_ls+=[float(input_cmd)]
        else:
            d_id_ls+=[input_cmd]

# %%
rd_dict = {}

def instert_key(dict_i, key_i, container_value='0'):            # Instert 
    dict_i[key_i] = container_value
#instert_key(a_dict, 'name', 'name')

def instert_keys_in_key(dict_i, key_i, container_value='0'):            # Instert 
    for i in dict_i:
        dict_i[i][key_i] = container_value
        
#instert_key(rd_dict, 'i', {})
#instert_key_in_key(rd_dict, 'a', [])
# rd_dict # {'i': {'a': []}}

def change_items(d_input, i_key, out_type='str'):             # Modify
    for i in d_input:
        print(i, i_key, '?', 'before:', d_input[i][i_key])
        itm = input('{}'.format(i))
        if itm == 'stop':
            return
        if itm == 'pass':
            pass
        if out_type == 'int' and itm != 'pass':
            d_input[i][i_key] = int(itm)
        elif out_type == 'float' and itm != 'pass':
            d_input[i][i_key] = float(itm)
        elif out_type == 'str' and itm != 'pass':
            d_input[i][i_key] = itm
        if out_type == 'list':
            d_input[i][i_key] = eval(itm)

#change_items(rd_dict, 'a', 'list')
#rd_dict
